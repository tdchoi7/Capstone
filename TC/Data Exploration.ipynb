# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Question 1
# - How does the issued loans vary year after year?
# - What are the purposes of applying **Lending Club** loans?
# - Do you observe different loan grade patterns for different loan purposes?
# - Do you observe different loan grade patterns in different years?
# - How about loan counts stratified into years and loan purposes/loan grades?

# %%
import csv
import pandas as pd
accepted = pd.read_csv('accepted_2007_to_2018Q4.csv')
# Out:
# /Users/viviannchan/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
accepted.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# 1     11.99       820.28     C        C1  ...                            NaN
# 2     10.78       432.66     B        B4  ...                            NaN
# 3     14.85       829.90     C        C5  ...                            NaN
# 4     22.45       289.91     F        F1  ...                            NaN
#
#   hardship_last_payment_amount disbursement_method  debt_settlement_flag  \
# 0                          NaN                Cash                     N
# 1                          NaN                Cash                     N
# 2                          NaN                Cash                     N
# 3                          NaN                Cash                     N
# 4                          NaN                Cash                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#   settlement_amount settlement_percentage settlement_term
# 0               NaN                   NaN             NaN
# 1               NaN                   NaN             NaN
# 2               NaN                   NaN             NaN
# 3               NaN                   NaN             NaN
# 4               NaN                   NaN             NaN
#
# [5 rows x 151 columns]

# %%
accepted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 151 entries, id to settlement_term
# dtypes: float64(113), object(38)
# memory usage: 2.5+ GB

# %%
accepted.describe()
# Out:
#        member_id     loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count        0.0  2.260668e+06  2.260668e+06     2.260668e+06  2.260668e+06
# mean         NaN  1.504693e+04  1.504166e+04     1.502344e+04  1.309283e+01
# std          NaN  9.190245e+03  9.188413e+03     9.192332e+03  4.832138e+00
# min          NaN  5.000000e+02  5.000000e+02     0.000000e+00  5.310000e+00
# 25%          NaN  8.000000e+03  8.000000e+03     8.000000e+03  9.490000e+00
# 50%          NaN  1.290000e+04  1.287500e+04     1.280000e+04  1.262000e+01
# 75%          NaN  2.000000e+04  2.000000e+04     2.000000e+04  1.599000e+01
# max          NaN  4.000000e+04  4.000000e+04     4.000000e+04  3.099000e+01
#
#         installment    annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  2.260668e+06  2.260664e+06  2.258957e+06  2.260639e+06    2.260668e+06
# mean   4.458068e+02  7.799243e+04  1.882420e+01  3.068792e-01    6.985882e+02
# std    2.671735e+02  1.126962e+05  1.418333e+01  8.672303e-01    3.301038e+01
# min    4.930000e+00  0.000000e+00 -1.000000e+00  0.000000e+00    6.100000e+02
# 25%    2.516500e+02  4.600000e+04  1.189000e+01  0.000000e+00    6.750000e+02
# 50%    3.779900e+02  6.500000e+04  1.784000e+01  0.000000e+00    6.900000e+02
# 75%    5.933200e+02  9.300000e+04  2.449000e+01  0.000000e+00    7.150000e+02
# max    1.719830e+03  1.100000e+08  9.990000e+02  5.800000e+01    8.450000e+02
#
#        ...  deferral_term  hardship_amount  hardship_length  hardship_dpd  \
# count  ...        10917.0     10917.000000          10917.0  10917.000000
# mean   ...            3.0       155.045981              3.0     13.743886
# std    ...            0.0       129.040594              0.0      9.671178
# min    ...            3.0         0.640000              3.0      0.000000
# 25%    ...            3.0        59.440000              3.0      5.000000
# 50%    ...            3.0       119.140000              3.0     15.000000
# 75%    ...            3.0       213.260000              3.0     22.000000
# max    ...            3.0       943.940000              3.0     37.000000
#
#        orig_projected_additional_accrued_interest  \
# count                                 8651.000000
# mean                                   454.798089
# std                                    375.385500
# min                                      1.920000
# 25%                                    175.230000
# 50%                                    352.770000
# 75%                                    620.175000
# max                                   2680.890000
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# count                    10917.000000                  10917.000000
# mean                     11636.883942                    193.994321
# std                       7625.988281                    198.629496
# min                         55.730000                      0.010000
# 25%                       5627.000000                     44.440000
# 50%                      10028.390000                    133.160000
# 75%                      16151.890000                    284.190000
# max                      40306.410000                   1407.860000
#
#        settlement_amount  settlement_percentage  settlement_term
# count       34246.000000           34246.000000     34246.000000
# mean         5010.664267              47.780365        13.191322
# std          3693.122590               7.311822         8.159980
# min            44.210000               0.200000         0.000000
# 25%          2208.000000              45.000000         6.000000
# 50%          4146.110000              45.000000        14.000000
# 75%          6850.172500              50.000000        18.000000
# max         33601.000000             521.350000       181.000000
#
# [8 rows x 113 columns]

# %%
accepted.issue_d.value_counts()
# Out:
# Mar-2016    61992
# Oct-2015    48631
# May-2018    46311
# Oct-2018    46305
# Aug-2018    46079
#             ...
# Aug-2007       74
# Jul-2007       63
# Sep-2008       57
# Sep-2007       53
# Jun-2007       24
# Name: issue_d, Length: 139, dtype: int64

# %%
test = accepted.iloc[0]

# %%
test['issue_d'].split("-")[1]
# Out:
# '2015'

# %%
test['year'] = test['issue_d'].split("-")[1]
test
# Out:
# /Users/viviannchan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# id                       68407277
# member_id                     NaN
# loan_amnt                    3600
# funded_amnt                  3600
# funded_amnt_inv              3600
#                            ...
# settlement_date               NaN
# settlement_amount             NaN
# settlement_percentage         NaN
# settlement_term               NaN
# year                         2015
# Name: 0, Length: 152, dtype: object

# %%
accepted['hardship_reason'].value_counts()
# Out:
# NATURAL_DISASTER         2965
# EXCESSIVE_OBLIGATIONS    2155
# UNEMPLOYMENT             1923
# INCOME_CURTAILMENT       1321
# MEDICAL                  1294
# REDUCED_HOURS             662
# DIVORCE                   225
# FAMILY_DEATH              214
# DISABILITY                158
# Name: hardship_reason, dtype: int64

# %%
accepted['loan_amnt'].describe()
# Out:
# count    2.260668e+06
# mean     1.504693e+04
# std      9.190245e+03
# min      5.000000e+02
# 25%      8.000000e+03
# 50%      1.290000e+04
# 75%      2.000000e+04
# max      4.000000e+04
# Name: loan_amnt, dtype: float64

# %%
accepted['grade'].value_counts()
# Out:
# B    663557
# C    650053
# A    433027
# D    324424
# E    135639
# F     41800
# G     12168
# Name: grade, dtype: int64

# %%
subset = accepted[['grade','issue_d','purpose']]

# %%
subset['issue_d'] = subset['issue_d'].astype(str)
subset['year'] = subset['issue_d'].apply(lambda x: x.split("-")[-1])
# Out:
# /Users/viviannchan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/viviannchan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
subset = subset.drop(['issue_d'], axis=1).dropna()
subset
# Out:
#         grade             purpose  year
# 0           C  debt_consolidation  2015
# 1           C      small_business  2015
# 2           B    home_improvement  2015
# 3           C  debt_consolidation  2015
# 4           F      major_purchase  2015
# ...       ...                 ...   ...
# 2260694     C    home_improvement  2016
# 2260695     B  debt_consolidation  2016
# 2260696     B  debt_consolidation  2016
# 2260697     C  debt_consolidation  2016
# 2260698     C  debt_consolidation  2016
#
# [2260668 rows x 3 columns]

# %%
subset['year'].value_counts()
# Out:
# 2018    495242
# 2017    443579
# 2016    434407
# 2015    421095
# 2014    235629
# 2013    134814
# 2012     53367
# 2011     21721
# 2010     12537
# 2009      5281
# 2008      2393
# 2007       603
# nan         33
# Name: year, dtype: int64

# %%
subset2 = subset.groupby(['year','grade'])['year'].count().unstack('grade').fillna(0)

# %%
# %pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
subset2.plot(kind='bar', stacked=True, figsize=(20,6))

# %%
subset2.plot(kind='bar', figsize=(20,6))
plt.legend(loc=2)

# %%
accepted['purpose'].value_counts()
# Out:
# debt_consolidation    1277877
# credit_card            516971
# home_improvement       150457
# other                  139440
# major_purchase          50445
# medical                 27488
# small_business          24689
# car                     24013
# vacation                15525
# moving                  15403
# house                   14136
# wedding                  2355
# renewable_energy         1445
# educational               424
# Name: purpose, dtype: int64

# %%
subset2
# Out:
# grade       A       B       C      D      E     F     G
# year
# 2007       78      98     141     99    100    52    35
# 2008      318     594     580    419    285   111    86
# 2009     1203    1445    1348    817    308   105    55
# 2010     2830    3687    2729   1885    962   311   133
# 2011     5754    6565    3942   2796   1739   722   203
# 2012    10901   18507   11875   7323   3185  1315   261
# 2013    17679   44116   38134  20569   9059  4393   864
# 2014    36108   61935   66565  42992  20121  6223  1685
# 2015    73336  117606  120567  62654  34948  9817  2167
# 2016    70847  134512  132178  59178  25807  9334  2551
# 2017    78796  133127  145144  56646  20167  6242  3457
# 2018   135177  141365  126850  69046  18958  3175   671

# %%
subset3 = subset.groupby(['year','purpose'])['year'].count().unstack('purpose').fillna(0)
subset3
# Out:
# purpose     car  credit_card  debt_consolidation  educational  \
# year
# 2007       13.0         87.0               207.0         36.0
# 2008       54.0        399.0               976.0         85.0
# 2009      191.0        626.0              2194.0        187.0
# 2010      419.0       1545.0              5729.0        114.0
# 2011      938.0       2820.0             10670.0          0.0
# 2012      901.0      10365.0             30811.0          0.0
# 2013     1050.0      32805.0             80640.0          0.0
# 2014     1832.0      55522.0            143006.0          0.0
# 2015     3466.0     102025.0            250020.0          1.0
# 2016     4813.0      91609.0            248899.0          0.0
# 2017     5357.0      91466.0            245083.0          1.0
# 2018     4979.0     127702.0            259642.0          0.0
#
# purpose  home_improvement   house  major_purchase  medical  moving    other  \
# year
# 2007                 36.0     8.0            10.0      9.0    15.0    113.0
# 2008                140.0    26.0            91.0     51.0    31.0    339.0
# 2009                388.0    72.0           258.0     91.0    67.0    659.0
# 2010                955.0   104.0           873.0    220.0   213.0   1443.0
# 2011               1680.0   216.0          1079.0    382.0   303.0   1871.0
# 2012               2893.0   418.0          1360.0    630.0   399.0   3053.0
# 2013               7404.0   675.0          2299.0    889.0   639.0   5843.0
# 2014              13045.0   750.0          3858.0   2331.0  1328.0  10371.0
# 2015              25293.0  1438.0          7449.0   3938.0  2420.0  19204.0
# 2016              31182.0  2002.0         10406.0   5440.0  3229.0  28469.0
# 2017              34693.0  2997.0         11140.0   6885.0  3644.0  33057.0
# 2018              32748.0  5430.0         11622.0   6622.0  3115.0  35018.0
#
# purpose  renewable_energy  small_business  vacation  wedding
# year
# 2007                  0.0            56.0       4.0      9.0
# 2008                  3.0           127.0      14.0     57.0
# 2009                  6.0           368.0      28.0    146.0
# 2010                 39.0           466.0     127.0    290.0
# 2011                 58.0           975.0     227.0    502.0
# 2012                 71.0          1386.0     344.0    736.0
# 2013                 51.0          1359.0     565.0    595.0
# 2014                123.0          2277.0    1178.0      8.0
# 2015                224.0          3364.0    2249.0      4.0
# 2016                304.0          4790.0    3262.0      2.0
# 2017                291.0          4938.0    4026.0      1.0
# 2018                275.0          4583.0    3501.0      5.0

# %%
subset3.plot(kind='bar', figsize=(20,6))
plt.legend(loc=2)

# %%
subset4 = subset.groupby(['grade','purpose'])['purpose'].count().unstack('grade').fillna(0)
subset4.plot(kind='bar', figsize=(20,6))
plt.legend(loc=2)

# %%
subset5 = subset.groupby(['year','grade','purpose'])['year'].count().unstack('grade').fillna(0)
subset5
# Out:
# grade                         A       B       C       D       E      F      G
# year purpose
# 2007 car                    3.0     2.0     3.0     2.0     1.0    2.0    0.0
#      credit_card            9.0    11.0    23.0    16.0    15.0    7.0    6.0
#      debt_consolidation    13.0    21.0    45.0    45.0    42.0   22.0   19.0
#      educational            5.0     6.0    11.0     3.0     7.0    3.0    1.0
#      home_improvement      10.0     9.0     4.0     6.0     4.0    2.0    1.0
# ...                         ...     ...     ...     ...     ...    ...    ...
# 2018 other               7333.0  9500.0  9329.0  6215.0  2178.0  363.0  100.0
#      renewable_energy      56.0    79.0    76.0    45.0    18.0    1.0    0.0
#      small_business       956.0  1188.0  1273.0   841.0   264.0   46.0   15.0
#      vacation             724.0   987.0   924.0   644.0   207.0   12.0    3.0
#      wedding                0.0     1.0     3.0     0.0     1.0    0.0    0.0
#
# [161 rows x 7 columns]

# %%
subset5.groupby(level="purpose").sum()
# Out:
# grade                      A         B         C         D        E        F  \
# purpose
# car                   6166.0    7385.0    6240.0    2891.0    987.0    275.0
# credit_card         140508.0  176750.0  130553.0   48764.0  15775.0   3757.0
# debt_consolidation  205916.0  361873.0  387312.0  200927.0  87262.0  26993.0
# educational             88.0     112.0     115.0      53.0     37.0     11.0
# home_improvement     34528.0   44325.0   40963.0   19267.0   8120.0   2514.0
# house                 2579.0    3282.0    3541.0    2465.0   1370.0    597.0
# major_purchase       11456.0   14638.0   13541.0    6875.0   2784.0    894.0
# medical               4459.0    7306.0    8320.0    4777.0   1919.0    575.0
# moving                1746.0    3402.0    4785.0    3276.0   1517.0    530.0
# other                19571.0   34451.0   42119.0   26434.0  11556.0   3944.0
# renewable_energy       179.0     321.0     419.0     298.0    151.0     59.0
# small_business        2963.0    4887.0    6671.0    5220.0   3009.0   1337.0
# vacation              2419.0    4271.0    4978.0    2671.0    931.0    211.0
# wedding                449.0     554.0     496.0     506.0    221.0    103.0
#
# grade                    G
# purpose
# car                   69.0
# credit_card          864.0
# debt_consolidation  7594.0
# educational            8.0
# home_improvement     740.0
# house                302.0
# major_purchase       257.0
# medical              132.0
# moving               147.0
# other               1365.0
# renewable_energy      18.0
# small_business       602.0
# vacation              44.0
# wedding               26.0

# %% [markdown]
# ## Rejected

# %%
rejected = pd.read_csv('rejected_2007_to_2018Q4.csv')

# %%
rejected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27648741 entries, 0 to 27648740
# Data columns (total 9 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Amount Requested      float64
#  1   Application Date      object
#  2   Loan Title            object
#  3   Risk_Score            float64
#  4   Debt-To-Income Ratio  object
#  5   Zip Code              object
#  6   State                 object
#  7   Employment Length     object
#  8   Policy Code           float64
# dtypes: float64(3), object(6)
# memory usage: 1.9+ GB

# %%
rejected.describe()
# Out:
#        Amount Requested    Risk_Score   Policy Code
# count      2.764874e+07  9.151111e+06  2.764782e+07
# mean       1.313324e+04  6.281721e+02  6.375113e-03
# std        1.500964e+04  8.993679e+01  1.127368e-01
# min        0.000000e+00  0.000000e+00  0.000000e+00
# 25%        4.800000e+03  5.910000e+02  0.000000e+00
# 50%        1.000000e+04  6.370000e+02  0.000000e+00
# 75%        2.000000e+04  6.750000e+02  0.000000e+00
# max        1.400000e+06  9.900000e+02  2.000000e+00

# %% [markdown]
# ## Loan Amount

# %%
accepted.groupby(['grade']).loan_amnt.describe()
# Out:
#           count          mean          std     min       25%      50%  \
# grade
# A      433027.0  14603.343210  9107.975657   500.0   8000.00  12000.0
# B      663557.0  14173.338199  8957.012601   500.0   7400.00  12000.0
# C      650053.0  15038.083318  9203.950054   500.0   8000.00  13000.0
# D      324424.0  15711.983007  9250.612823   500.0   8575.00  14400.0
# E      135639.0  17453.078392  9363.276694   600.0  10000.00  16000.0
# F       41800.0  19124.646531  9166.366254  1000.0  12000.00  18175.0
# G       12168.0  20383.988741  8994.472986   600.0  13193.75  19800.0
#
#             75%      max
# grade
# A      20000.00  40000.0
# B      20000.00  40000.0
# C      20000.00  40000.0
# D      21200.00  40000.0
# E      24175.00  40000.0
# F      25600.00  40000.0
# G      27656.25  40000.0

# %%
grade_amnt = accepted[['grade','loan_amnt']]
grade_amnt.boxplot(by='grade',column='loan_amnt',figsize=(12,6))

# %%
accepted['loan_status'].value_counts()
# Out:
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: loan_status, dtype: int64

# %% [markdown]
# ## Interest Rate

# %%
grade_intrate = accepted[['grade','int_rate']]
grade_intrate.boxplot(by='grade',column='int_rate',figsize=(12,6))

# %%
accepted['funded_amnt_inv'].value_counts()
# Out:
# 10000.000000    177561
# 20000.000000    120453
# 15000.000000    114539
# 12000.000000    114068
# 5000.000000      81999
#                  ...
# 16377.711747         1
# 13707.002692         1
# 7043.480621          1
# 8605.206744          1
# 2536.980000          1
# Name: funded_amnt_inv, Length: 10057, dtype: int64
