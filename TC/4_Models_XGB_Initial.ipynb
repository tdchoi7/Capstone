# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

from matplotlib import pyplot as plt

from sklearn import model_selection as ms
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier

import xgboost as xgb

import gzip

import import_ipynb
from My_Functions import null_cols, rmse
# Out:
# importing Jupyter notebook from My_Functions.ipynb

# %%
acc_initial = pd.read_csv("acc_initial.csv.gz",
                          compression='gzip',
                          header=0,
                          sep=',',
                          quotechar='"')

target_initial = pd.read_csv("target_initial.csv.gz",
                             compression='gzip',
                             header=0,
                             sep=',',
                             quotechar='"')

acc_initial_ds = pd.read_csv("acc_initial_downsample.csv.gz",
                             compression='gzip',
                             header=0,
                             sep=',',
                             quotechar='"')

target_initial_ds = pd.read_csv("target_initial_downsample.csv.gz",
                                compression='gzip',
                                header=0,
                                sep=',',
                                quotechar='"')

# %%
state=0

# downsampled:
xtrain, xtest, ytrain, ytest = ms.train_test_split(acc_initial,
                                                   target_initial,
                                                   test_size=0.2,
                                                   random_state=state)

# Must flatten to fit
ytrain = ytrain.values.flatten()

# downsampled:
xtrain_ds, xtest_ds, ytrain_ds, ytest_ds = ms.train_test_split(acc_initial_ds,
                                                               target_initial_ds,
                                                               test_size=0.2,
                                                               random_state=state)

# Must flatten to fit
ytrain_ds = ytrain_ds.values.flatten()


# using standard kfold split
n_folds = ms.KFold(n_splits=5, random_state=state, shuffle=True)

# %% [markdown]
# ## Original Data

# %%
xgb_clsfr = xgb.XGBClassifier()

train_scores = []
test_scores = []
train_rmse = []
test_rmse = []
best_par_list = []

objective_ = ['binary:logistic']
evalmetric = ['auc']
uselabelencoder = [False]
treemethod = ['gpu_hist']
predictor_ = ['gpu_predictor']
njobs = [-1]
randomstate = [state]
booster_ = ['gbtree']

# nestimators = [100]
# minchildweight = [1, 5]
# maxdepth = [1, 3]
# learningrate = [0.1, 1]
# gamma_ = [0.5, 2]
# subsample_ = [0.8, 1]
# colsamplebytree = [0.8, 1]


gparam_xgb = {'objective': objective_,
                 'eval_metric': evalmetric,
                 'use_label_encoder': uselabelencoder,
                 'tree_method': treemethod,
                 'predictor': predictor_,
                 'n_jobs': njobs,
                 'booster': booster_,
#               'n_estimators': nestimators,
#               'min_child_weight': minchildweight,
#               'max_depth': maxdepth,
#               'learning_rate': learningrate,
#               'gamma': gamma_,
#               'subsample': subsample_,
#               'colsample_bytree': colsamplebytree,
                 'random_state': randomstate}


gs_xgb = ms.GridSearchCV(xgb_clsfr, gparam_xgb, cv=n_folds, refit=True, n_jobs=-1,
                          scoring='roc_auc', return_train_score=True)

# %time gs_xgb.fit(xtrain, ytrain)

# setting up dataframe for results
train_scores.append(gs_xgb.best_estimator_.score(xtrain, ytrain))
test_scores.append(gs_xgb.best_estimator_.score(xtest, ytest))


# use rmse function from Self_Written_Functions_Sheet_Recover
train_rmse.append(rmse(gs_xgb, ytrain, xtrain))
test_rmse.append(rmse(gs_xgb, ytest, xtest))

# add the best parameters to the df
best_par_list.append(gs_xgb.best_params_)

# find the difference btwn the rmses
diff_rmse = np.subtract(train_rmse, test_rmse)

# create dataframe
list_results = [train_scores, test_scores, train_rmse, test_rmse, diff_rmse]
res_df = pd.DataFrame(list_results).T
res_df.columns = ['TrainScores', 'TestScores', 'TrainRMSE', 'TestRMSE', 'DiffRMSE']
best_par_df = pd.DataFrame(best_par_list)
res_df = pd.concat([res_df, best_par_df], axis=1, sort=False)

# confusion matrix for train set
print('\n')
print('confusion matrix for train set')
print(confusion_matrix(ytrain, gs_xgb.predict(xtrain)))

# confusion matrix for test set
print('\n')
print('confusion matrix for test set')
print(confusion_matrix(ytest, gs_xgb.predict(xtest)))

res_df
# Out:
# Wall time: 29.1 s
#
#
# confusion matrix for train set
# [[423705   7662]
#  [ 91657  16216]]
#
#
# confusion matrix for test set
# [[105392   2611]
#  [ 23724   3083]]
#    TrainScores  TestScores  TrainRMSE  TestRMSE  DiffRMSE booster eval_metric  \
# 0     0.815817    0.804651   0.429166  0.441983 -0.012817  gbtree         auc
#
#    n_jobs        objective      predictor  random_state tree_method  \
# 0      -1  binary:logistic  gpu_predictor             0    gpu_hist
#
#    use_label_encoder
# 0              False

# %%
sorted_importance = sorted(zip(xtrain.columns,
                               gs_xgb.best_estimator_.feature_importances_),
                           key=lambda t:t[1], reverse=True)
sorted_importance
# Out:
# [('int_rate', 0.121761814),
#  ('grade_B', 0.087953016),
#  ('term_ 60 months', 0.037270594),
#  ('grade_D', 0.024362464),
#  ('grade_C', 0.019149711),
#  ('mort_acc', 0.01621906),
#  ('funded_amnt', 0.015606522),
#  ('home_ownership_RENT', 0.015461577),
#  ('home_ownership_MORTGAGE', 0.014098574),
#  ('sub_grade_B5', 0.0124700675),
#  ('acc_open_past_24mths', 0.01228732),
#  ('avg_cur_bal', 0.012106737),
#  ('purpose_small_business', 0.010992833),
#  ('total_cu_tl', 0.0104447715),
#  ('sub_grade_B4', 0.010367051),
#  ('fico_range_low', 0.010282504),
#  ('max_bal_bc', 0.009565598),
#  ('num_actv_rev_tl', 0.009511937),
#  ('dti', 0.009328223),
#  ('funded_amnt_inv', 0.008639677),
#  ('purpose_medical', 0.008156328),
#  ('annual_inc', 0.008058833),
#  ('initial_list_status_w', 0.008058231),
#  ('sub_grade_C1', 0.007987082),
#  ('sub_grade_D3', 0.007881918),
#  ('verification_status_Source Verified', 0.00736332),
#  ('loan_amnt', 0.0073133656),
#  ('all_util', 0.0072429543),
#  ('tot_hi_cred_lim', 0.007127619),
#  ('total_bal_il', 0.0070407474),
#  ('installment', 0.006996089),
#  ('verification_status_Verified', 0.0069587333),
#  ('total_bc_limit', 0.0066758962),
#  ('sec_app_fico_range_low', 0.0066716084),
#  ('collections_12_mths_ex_med', 0.0066712704),
#  ('purpose_vacation', 0.00650769),
#  ('sub_grade_D1', 0.0064217793),
#  ('mths_since_recent_inq', 0.006379915),
#  ('sec_app_inq_last_6mths', 0.0060058814),
#  ('emp_length_10 years', 0.00587492),
#  ('mo_sin_old_rev_tl_op', 0.005796463),
#  ('verification_status_joint_Verified', 0.005773107),
#  ('total_rev_hi_lim', 0.005645563),
#  ('num_rev_tl_bal_gt_0', 0.0055784383),
#  ('dti_joint', 0.005557287),
#  ('delinq_2yrs', 0.005339755),
#  ('emp_length_7 years', 0.0053366767),
#  ('grade_G', 0.0053137),
#  ('mths_since_recent_bc', 0.0052978215),
#  ('num_actv_bc_tl', 0.0051895916),
#  ('open_act_il', 0.0051655374),
#  ('sub_grade_C2', 0.0051623993),
#  ('purpose_credit_card', 0.0050783125),
#  ('grade_F', 0.0050556553),
#  ('sub_grade_E4', 0.0050506694),
#  ('revol_bal', 0.004960554),
#  ('bc_open_to_buy', 0.0049112453),
#  ('mths_since_last_record', 0.0049016997),
#  ('total_il_high_credit_limit', 0.004841764),
#  ('pub_rec_bankruptcies', 0.0048185256),
#  ('mo_sin_rcnt_tl', 0.004752862),
#  ('purpose_moving', 0.004735945),
#  ('purpose_major_purchase', 0.004730378),
#  ('delinq_amnt', 0.0047216536),
#  ('emp_length_9 years', 0.0047185267),
#  ('percent_bc_gt_75', 0.004706058),
#  ('sub_grade_E5', 0.0046976334),
#  ('total_acc', 0.004680711),
#  ('grade_E', 0.004645642),
#  ('bc_util', 0.0046337615),
#  ('mths_since_last_delinq', 0.004541705),
#  ('mths_since_rcnt_il', 0.0045414316),
#  ('num_il_tl', 0.0044768234),
#  ('purpose_other', 0.004462759),
#  ('num_rev_accts', 0.004423308),
#  ('sub_grade_A3', 0.004418744),
#  ('pct_tl_nvr_dlq', 0.004380004),
#  ('num_bc_sats', 0.004340533),
#  ('mths_since_last_major_derog', 0.004304777),
#  ('sub_grade_C3', 0.004284893),
#  ('sub_grade_A2', 0.004220783),
#  ('sub_grade_E3', 0.0042095236),
#  ('sub_grade_C4', 0.0042026713),
#  ('mo_sin_old_il_acct', 0.004189248),
#  ('emp_length_5 years', 0.004124542),
#  ('sub_grade_E2', 0.004107882),
#  ('acc_now_delinq', 0.0041053635),
#  ('tot_cur_bal', 0.0041039134),
#  ('revol_util', 0.00400326),
#  ('purpose_renewable_energy', 0.0039605945),
#  ('total_bal_ex_mort', 0.0039605116),
#  ('sec_app_revol_util', 0.0039577824),
#  ('purpose_house', 0.003912034),
#  ('num_op_rev_tl', 0.0038815509),
#  ('num_sats', 0.0038608413),
#  ('sub_grade_A5', 0.003803069),
#  ('inq_fi', 0.0037945327),
#  ('il_util', 0.0037632387),
#  ('home_ownership_OWN', 0.0037347453),
#  ('mths_since_recent_bc_dlq', 0.0037058147),
#  ('sec_app_open_act_il', 0.0036837338),
#  ('emp_length_3 years', 0.0036790145),
#  ('revol_bal_joint', 0.0036739383),
#  ('purpose_debt_consolidation', 0.0036508583),
#  ('emp_length_2 years', 0.0036143786),
#  ('tot_coll_amt', 0.0036012647),
#  ('mths_since_recent_revol_delinq', 0.003600292),
#  ('purpose_home_improvement', 0.0035882064),
#  ('annual_inc_joint', 0.0035839665),
#  ('num_bc_tl', 0.003552578),
#  ('emp_length_8 years', 0.0035082465),
#  ('sub_grade_B1', 0.0035014062),
#  ('tax_liens', 0.0034836743),
#  ('sub_grade_E1', 0.0034796495),
#  ('sub_grade_G1', 0.0034592606),
#  ('open_acc', 0.0034070616),
#  ('mo_sin_rcnt_rev_tl_op', 0.0033977486),
#  ('sec_app_mort_acc', 0.0033104764),
#  ('sec_app_open_acc', 0.0031928513),
#  ('chargeoff_within_12_mths', 0.0031905507),
#  ('emp_length_6 years', 0.0031677051),
#  ('sub_grade_D4', 0.0031237393),
#  ('pub_rec', 0.0030336461),
#  ('sub_grade_B2', 0.0030287614),
#  ('sec_app_mths_since_last_major_derog', 0.0030099414),
#  ('sub_grade_D5', 0.0030052972),
#  ('emp_length_4 years', 0.0029838805),
#  ('sub_grade_F3', 0.002817065),
#  ('sub_grade_D2', 0.00274926),
#  ('sec_app_num_rev_accts', 0.0026703738),
#  ('sub_grade_G4', 0.0026361875),
#  ('emp_length_1 year', 0.0024276103),
#  ('sub_grade_B3', 0.0023568457),
#  ('sub_grade_G5', 0.002220872),
#  ('sub_grade_C5', 0.0019659316),
#  ('home_ownership_OTHER', 0.0018986329),
#  ('purpose_wedding', 0.0013226083),
#  ('verification_status_joint_Source Verified', 0.0005734667),
#  ('fico_range_high', 0.0),
#  ('policy_code', 0.0),
#  ('sec_app_fico_range_high', 0.0),
#  ('sub_grade_A4', 0.0),
#  ('sub_grade_F1', 0.0),
#  ('sub_grade_F2', 0.0),
#  ('sub_grade_F4', 0.0),
#  ('sub_grade_F5', 0.0),
#  ('sub_grade_G2', 0.0),
#  ('sub_grade_G3', 0.0),
#  ('home_ownership_NONE', 0.0),
#  ('purpose_educational', 0.0),
#  ('application_type_Joint App', 0.0)]

# %%
from sklearn.metrics import average_precision_score
average_precision = average_precision_score(ytest, gs_xgb.predict(xtest))

print('Average precision-recall score for random forest: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score for random forest: 0.24

# %%
# Precision-Recall curve
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve

disp = plot_precision_recall_curve(gs_xgb, xtest, ytest)
disp.ax_.set_title('2-class Precision-Recall curve for random forest: '
                   'AP={0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, '2-class Precision-Recall curve for random forest: AP=0.24')

# %%
# F1 score 
# F1 = 2 * (precision * recall) / (precision + recall)

f1_score = metrics.f1_score(ytest, gs_xgb.predict(xtest))
recall_score = metrics.recall_score(ytest, gs_xgb.predict(xtest))
precision_score = metrics.precision_score(ytest, gs_xgb.predict(xtest))
print ("Random forest performance")
print ('-'*70)
print('F1 score: {0:0.2f}'.format(f1_score))
print('recall score: {0:0.2f}'.format(recall_score))
print('precision score: {0:0.2f}'.format(precision_score))
# Out:
# Random forest performance
# ----------------------------------------------------------------------
# F1 score: 0.19
# recall score: 0.12
# precision score: 0.54

# %%
# ROC-AUC score
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html#sklearn.metrics.roc_auc_score

from sklearn.metrics import roc_auc_score
print ("Random forest ROC-AUC score")
print ('-'*70)
roc_auc_score(ytest, gs_xgb.predict(xtest))
# Out:
# Random forest ROC-AUC score
# ----------------------------------------------------------------------
# 0.5454160099141693

# %%
# Receiver operating characteristic (ROC) curve
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_roc_curve.html#sklearn.metrics.plot_roc_curve

from sklearn import metrics
metrics.plot_roc_curve(gs_xgb.best_estimator_, xtest, ytest)

# %%
filtered_sorted_importance = [x for x in sorted_importance if x[1]>0.003]
filtered_sorted_importance
# Out:
# [('int_rate', 0.121761814),
#  ('grade_B', 0.087953016),
#  ('term_ 60 months', 0.037270594),
#  ('grade_D', 0.024362464),
#  ('grade_C', 0.019149711),
#  ('mort_acc', 0.01621906),
#  ('funded_amnt', 0.015606522),
#  ('home_ownership_RENT', 0.015461577),
#  ('home_ownership_MORTGAGE', 0.014098574),
#  ('sub_grade_B5', 0.0124700675),
#  ('acc_open_past_24mths', 0.01228732),
#  ('avg_cur_bal', 0.012106737),
#  ('purpose_small_business', 0.010992833),
#  ('total_cu_tl', 0.0104447715),
#  ('sub_grade_B4', 0.010367051),
#  ('fico_range_low', 0.010282504),
#  ('max_bal_bc', 0.009565598),
#  ('num_actv_rev_tl', 0.009511937),
#  ('dti', 0.009328223),
#  ('funded_amnt_inv', 0.008639677),
#  ('purpose_medical', 0.008156328),
#  ('annual_inc', 0.008058833),
#  ('initial_list_status_w', 0.008058231),
#  ('sub_grade_C1', 0.007987082),
#  ('sub_grade_D3', 0.007881918),
#  ('verification_status_Source Verified', 0.00736332),
#  ('loan_amnt', 0.0073133656),
#  ('all_util', 0.0072429543),
#  ('tot_hi_cred_lim', 0.007127619),
#  ('total_bal_il', 0.0070407474),
#  ('installment', 0.006996089),
#  ('verification_status_Verified', 0.0069587333),
#  ('total_bc_limit', 0.0066758962),
#  ('sec_app_fico_range_low', 0.0066716084),
#  ('collections_12_mths_ex_med', 0.0066712704),
#  ('purpose_vacation', 0.00650769),
#  ('sub_grade_D1', 0.0064217793),
#  ('mths_since_recent_inq', 0.006379915),
#  ('sec_app_inq_last_6mths', 0.0060058814),
#  ('emp_length_10 years', 0.00587492),
#  ('mo_sin_old_rev_tl_op', 0.005796463),
#  ('verification_status_joint_Verified', 0.005773107),
#  ('total_rev_hi_lim', 0.005645563),
#  ('num_rev_tl_bal_gt_0', 0.0055784383),
#  ('dti_joint', 0.005557287),
#  ('delinq_2yrs', 0.005339755),
#  ('emp_length_7 years', 0.0053366767),
#  ('grade_G', 0.0053137),
#  ('mths_since_recent_bc', 0.0052978215),
#  ('num_actv_bc_tl', 0.0051895916),
#  ('open_act_il', 0.0051655374),
#  ('sub_grade_C2', 0.0051623993),
#  ('purpose_credit_card', 0.0050783125),
#  ('grade_F', 0.0050556553),
#  ('sub_grade_E4', 0.0050506694),
#  ('revol_bal', 0.004960554),
#  ('bc_open_to_buy', 0.0049112453),
#  ('mths_since_last_record', 0.0049016997),
#  ('total_il_high_credit_limit', 0.004841764),
#  ('pub_rec_bankruptcies', 0.0048185256),
#  ('mo_sin_rcnt_tl', 0.004752862),
#  ('purpose_moving', 0.004735945),
#  ('purpose_major_purchase', 0.004730378),
#  ('delinq_amnt', 0.0047216536),
#  ('emp_length_9 years', 0.0047185267),
#  ('percent_bc_gt_75', 0.004706058),
#  ('sub_grade_E5', 0.0046976334),
#  ('total_acc', 0.004680711),
#  ('grade_E', 0.004645642),
#  ('bc_util', 0.0046337615),
#  ('mths_since_last_delinq', 0.004541705),
#  ('mths_since_rcnt_il', 0.0045414316),
#  ('num_il_tl', 0.0044768234),
#  ('purpose_other', 0.004462759),
#  ('num_rev_accts', 0.004423308),
#  ('sub_grade_A3', 0.004418744),
#  ('pct_tl_nvr_dlq', 0.004380004),
#  ('num_bc_sats', 0.004340533),
#  ('mths_since_last_major_derog', 0.004304777),
#  ('sub_grade_C3', 0.004284893),
#  ('sub_grade_A2', 0.004220783),
#  ('sub_grade_E3', 0.0042095236),
#  ('sub_grade_C4', 0.0042026713),
#  ('mo_sin_old_il_acct', 0.004189248),
#  ('emp_length_5 years', 0.004124542),
#  ('sub_grade_E2', 0.004107882),
#  ('acc_now_delinq', 0.0041053635),
#  ('tot_cur_bal', 0.0041039134),
#  ('revol_util', 0.00400326),
#  ('purpose_renewable_energy', 0.0039605945),
#  ('total_bal_ex_mort', 0.0039605116),
#  ('sec_app_revol_util', 0.0039577824),
#  ('purpose_house', 0.003912034),
#  ('num_op_rev_tl', 0.0038815509),
#  ('num_sats', 0.0038608413),
#  ('sub_grade_A5', 0.003803069),
#  ('inq_fi', 0.0037945327),
#  ('il_util', 0.0037632387),
#  ('home_ownership_OWN', 0.0037347453),
#  ('mths_since_recent_bc_dlq', 0.0037058147),
#  ('sec_app_open_act_il', 0.0036837338),
#  ('emp_length_3 years', 0.0036790145),
#  ('revol_bal_joint', 0.0036739383),
#  ('purpose_debt_consolidation', 0.0036508583),
#  ('emp_length_2 years', 0.0036143786),
#  ('tot_coll_amt', 0.0036012647),
#  ('mths_since_recent_revol_delinq', 0.003600292),
#  ('purpose_home_improvement', 0.0035882064),
#  ('annual_inc_joint', 0.0035839665),
#  ('num_bc_tl', 0.003552578),
#  ('emp_length_8 years', 0.0035082465),
#  ('sub_grade_B1', 0.0035014062),
#  ('tax_liens', 0.0034836743),
#  ('sub_grade_E1', 0.0034796495),
#  ('sub_grade_G1', 0.0034592606),
#  ('open_acc', 0.0034070616),
#  ('mo_sin_rcnt_rev_tl_op', 0.0033977486),
#  ('sec_app_mort_acc', 0.0033104764),
#  ('sec_app_open_acc', 0.0031928513),
#  ('chargeoff_within_12_mths', 0.0031905507),
#  ('emp_length_6 years', 0.0031677051),
#  ('sub_grade_D4', 0.0031237393),
#  ('pub_rec', 0.0030336461),
#  ('sub_grade_B2', 0.0030287614),
#  ('sec_app_mths_since_last_major_derog', 0.0030099414),
#  ('sub_grade_D5', 0.0030052972)]

# %%
# get list of column names for easier application in the future
filter_important = []
for tup in filtered_sorted_importance:
    filter_important.append(tup[0])

filter_important
# Out:
# ['int_rate',
#  'grade_B',
#  'term_ 60 months',
#  'grade_D',
#  'grade_C',
#  'mort_acc',
#  'funded_amnt',
#  'home_ownership_RENT',
#  'home_ownership_MORTGAGE',
#  'sub_grade_B5',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'purpose_small_business',
#  'total_cu_tl',
#  'sub_grade_B4',
#  'fico_range_low',
#  'max_bal_bc',
#  'num_actv_rev_tl',
#  'dti',
#  'funded_amnt_inv',
#  'purpose_medical',
#  'annual_inc',
#  'initial_list_status_w',
#  'sub_grade_C1',
#  'sub_grade_D3',
#  'verification_status_Source Verified',
#  'loan_amnt',
#  'all_util',
#  'tot_hi_cred_lim',
#  'total_bal_il',
#  'installment',
#  'verification_status_Verified',
#  'total_bc_limit',
#  'sec_app_fico_range_low',
#  'collections_12_mths_ex_med',
#  'purpose_vacation',
#  'sub_grade_D1',
#  'mths_since_recent_inq',
#  'sec_app_inq_last_6mths',
#  'emp_length_10 years',
#  'mo_sin_old_rev_tl_op',
#  'verification_status_joint_Verified',
#  'total_rev_hi_lim',
#  'num_rev_tl_bal_gt_0',
#  'dti_joint',
#  'delinq_2yrs',
#  'emp_length_7 years',
#  'grade_G',
#  'mths_since_recent_bc',
#  'num_actv_bc_tl',
#  'open_act_il',
#  'sub_grade_C2',
#  'purpose_credit_card',
#  'grade_F',
#  'sub_grade_E4',
#  'revol_bal',
#  'bc_open_to_buy',
#  'mths_since_last_record',
#  'total_il_high_credit_limit',
#  'pub_rec_bankruptcies',
#  'mo_sin_rcnt_tl',
#  'purpose_moving',
#  'purpose_major_purchase',
#  'delinq_amnt',
#  'emp_length_9 years',
#  'percent_bc_gt_75',
#  'sub_grade_E5',
#  'total_acc',
#  'grade_E',
#  'bc_util',
#  'mths_since_last_delinq',
#  'mths_since_rcnt_il',
#  'num_il_tl',
#  'purpose_other',
#  'num_rev_accts',
#  'sub_grade_A3',
#  'pct_tl_nvr_dlq',
#  'num_bc_sats',
#  'mths_since_last_major_derog',
#  'sub_grade_C3',
#  'sub_grade_A2',
#  'sub_grade_E3',
#  'sub_grade_C4',
#  'mo_sin_old_il_acct',
#  'emp_length_5 years',
#  'sub_grade_E2',
#  'acc_now_delinq',
#  'tot_cur_bal',
#  'revol_util',
#  'purpose_renewable_energy',
#  'total_bal_ex_mort',
#  'sec_app_revol_util',
#  'purpose_house',
#  'num_op_rev_tl',
#  'num_sats',
#  'sub_grade_A5',
#  'inq_fi',
#  'il_util',
#  'home_ownership_OWN',
#  'mths_since_recent_bc_dlq',
#  'sec_app_open_act_il',
#  'emp_length_3 years',
#  'revol_bal_joint',
#  'purpose_debt_consolidation',
#  'emp_length_2 years',
#  'tot_coll_amt',
#  'mths_since_recent_revol_delinq',
#  'purpose_home_improvement',
#  'annual_inc_joint',
#  'num_bc_tl',
#  'emp_length_8 years',
#  'sub_grade_B1',
#  'tax_liens',
#  'sub_grade_E1',
#  'sub_grade_G1',
#  'open_acc',
#  'mo_sin_rcnt_rev_tl_op',
#  'sec_app_mort_acc',
#  'sec_app_open_acc',
#  'chargeoff_within_12_mths',
#  'emp_length_6 years',
#  'sub_grade_D4',
#  'pub_rec',
#  'sub_grade_B2',
#  'sec_app_mths_since_last_major_derog',
#  'sub_grade_D5']

# %% [markdown]
# # Downsampled Data

# %%
xgb_clsfr_ds = xgb.XGBClassifier()

train_scores = []
test_scores = []
train_rmse = []
test_rmse = []
best_par_list = []

objective_ = ['binary:logistic']
evalmetric = ['auc']
uselabelencoder = [False]
treemethod = ['gpu_hist']
predictor_ = ['gpu_predictor']
njobs = [-1]
randomstate = [state]
booster_ = ['gbtree']

# nestimators = [100]
# minchildweight = [1, 5]
# maxdepth = [1, 3]
# learningrate = [0.1, 1]
# gamma_ = [0.5, 2]
# subsample_ = [0.8, 1]
# colsamplebytree = [0.8, 1]


gparam_xgb_ds = {'objective': objective_,
                 'eval_metric': evalmetric,
                 'use_label_encoder': uselabelencoder,
                 'tree_method': treemethod,
                 'predictor': predictor_,
                 'n_jobs': njobs,
                 'booster': booster_,
#               'n_estimators': nestimators,
#               'min_child_weight': minchildweight,
#               'max_depth': maxdepth,
#               'learning_rate': learningrate,
#               'gamma': gamma_,
#               'subsample': subsample_,
#               'colsample_bytree': colsamplebytree,
                 'random_state': randomstate}


gs_xgb_ds = ms.GridSearchCV(xgb_clsfr_ds, gparam_xgb_ds, cv=n_folds, refit=True, n_jobs=-1,
                          scoring='roc_auc', return_train_score=True)

# %time gs_xgb_ds.fit(xtrain_ds, ytrain_ds)

# setting up dataframe for results
train_scores.append(gs_xgb_ds.best_estimator_.score(xtrain_ds, ytrain_ds))
test_scores.append(gs_xgb_ds.best_estimator_.score(xtest_ds, ytest_ds))


# use rmse function from Self_Written_Functions_Sheet_Recover
train_rmse.append(rmse(gs_xgb_ds, ytrain_ds, xtrain_ds))
test_rmse.append(rmse(gs_xgb_ds, ytest_ds, xtest_ds))

# add the best parameters to the df
best_par_list.append(gs_xgb_ds.best_params_)

# find the difference btwn the rmses
diff_rmse = np.subtract(train_rmse, test_rmse)

# create dataframe
list_results = [train_scores, test_scores, train_rmse, test_rmse, diff_rmse]
res_df = pd.DataFrame(list_results).T
res_df.columns = ['TrainScores', 'TestScores', 'TrainRMSE', 'TestRMSE', 'DiffRMSE']
best_par_df = pd.DataFrame(best_par_list)
res_df = pd.concat([res_df, best_par_df], axis=1, sort=False)

# confusion matrix for train set
print('\n')
print('confusion matrix for train set')
print(confusion_matrix(ytrain_ds, gs_xgb_ds.predict(xtrain_ds)))

# confusion matrix for test set
print('\n')
print('confusion matrix for test set')
print(confusion_matrix(ytest_ds, gs_xgb_ds.predict(xtest_ds)))

res_df
# Out:
# Wall time: 15.2 s
#
#
# confusion matrix for train set
# [[75640 32070]
#  [29570 78208]]
#
#
# confusion matrix for test set
# [[17497  9473]
#  [ 8625 18277]]
#    TrainScores  TestScores  TrainRMSE  TestRMSE  DiffRMSE booster eval_metric  \
# 0     0.713952    0.664056   0.534835  0.579607 -0.044772  gbtree         auc
#
#    n_jobs        objective      predictor  random_state tree_method  \
# 0      -1  binary:logistic  gpu_predictor             0    gpu_hist
#
#    use_label_encoder
# 0              False

# %%
sorted_importance = sorted(zip(xtrain_ds.columns,
                               gs_xgb_ds.best_estimator_.feature_importances_),
                           key=lambda t:t[1], reverse=True)
sorted_importance
# Out:
# [('int_rate', 0.13495792),
#  ('term_ 60 months', 0.04060569),
#  ('grade_C', 0.029782958),
#  ('home_ownership_MORTGAGE', 0.02616637),
#  ('grade_D', 0.020567523),
#  ('grade_B', 0.018797182),
#  ('home_ownership_RENT', 0.015427485),
#  ('avg_cur_bal', 0.013304356),
#  ('acc_open_past_24mths', 0.013275657),
#  ('mort_acc', 0.011543607),
#  ('purpose_small_business', 0.010741185),
#  ('num_actv_rev_tl', 0.010709896),
#  ('total_cu_tl', 0.010606778),
#  ('dti', 0.010114022),
#  ('funded_amnt', 0.009562384),
#  ('sec_app_fico_range_low', 0.009561759),
#  ('fico_range_low', 0.009349659),
#  ('all_util', 0.009177409),
#  ('sub_grade_C1', 0.008891337),
#  ('funded_amnt_inv', 0.008700782),
#  ('installment', 0.00844077),
#  ('annual_inc', 0.008371061),
#  ('delinq_2yrs', 0.008290611),
#  ('max_bal_bc', 0.008184841),
#  ('sub_grade_C2', 0.0077762464),
#  ('sub_grade_F1', 0.007593634),
#  ('verification_status_Source Verified', 0.0075656804),
#  ('purpose_vacation', 0.007373285),
#  ('loan_amnt', 0.0072820135),
#  ('initial_list_status_w', 0.007158256),
#  ('dti_joint', 0.007085065),
#  ('sub_grade_C4', 0.0070668864),
#  ('verification_status_Verified', 0.007045906),
#  ('total_bal_il', 0.006600677),
#  ('collections_12_mths_ex_med', 0.0063952636),
#  ('sub_grade_D5', 0.006362297),
#  ('grade_F', 0.0063594235),
#  ('tot_hi_cred_lim', 0.006302484),
#  ('mths_since_recent_inq', 0.0062654614),
#  ('acc_now_delinq', 0.0062138303),
#  ('mo_sin_old_rev_tl_op', 0.0062007974),
#  ('sec_app_mort_acc', 0.005859379),
#  ('purpose_renewable_energy', 0.005836658),
#  ('purpose_medical', 0.005819855),
#  ('sec_app_inq_last_6mths', 0.005724339),
#  ('sub_grade_E3', 0.005622854),
#  ('sub_grade_D2', 0.0056137205),
#  ('emp_length_4 years', 0.005555141),
#  ('sub_grade_A3', 0.0055534914),
#  ('sub_grade_F4', 0.005488423),
#  ('emp_length_10 years', 0.0054540024),
#  ('sub_grade_E1', 0.005438348),
#  ('open_act_il', 0.00543798),
#  ('mths_since_last_record', 0.0053850943),
#  ('total_bc_limit', 0.0053547113),
#  ('total_rev_hi_lim', 0.005354496),
#  ('sub_grade_A5', 0.005335519),
#  ('mths_since_recent_bc', 0.0053325673),
#  ('bc_open_to_buy', 0.0053218273),
#  ('sub_grade_A2', 0.005212536),
#  ('percent_bc_gt_75', 0.0051928875),
#  ('revol_bal', 0.005091662),
#  ('bc_util', 0.005049705),
#  ('num_rev_accts', 0.0050191474),
#  ('sub_grade_E2', 0.005001006),
#  ('num_actv_bc_tl', 0.0049951673),
#  ('sub_grade_D3', 0.0049714916),
#  ('mths_since_last_delinq', 0.0048800595),
#  ('pct_tl_nvr_dlq', 0.0048671803),
#  ('sub_grade_B2', 0.00484784),
#  ('purpose_house', 0.0048164725),
#  ('num_rev_tl_bal_gt_0', 0.004765408),
#  ('total_il_high_credit_limit', 0.004762313),
#  ('mo_sin_rcnt_tl', 0.0047621056),
#  ('num_il_tl', 0.0046917014),
#  ('sub_grade_F5', 0.0046688216),
#  ('mths_since_rcnt_il', 0.004668653),
#  ('emp_length_9 years', 0.004643099),
#  ('emp_length_3 years', 0.0046409555),
#  ('sub_grade_G4', 0.0046368837),
#  ('mo_sin_rcnt_rev_tl_op', 0.0046221297),
#  ('sub_grade_D1', 0.0046168584),
#  ('purpose_debt_consolidation', 0.0045453627),
#  ('tot_coll_amt', 0.004527774),
#  ('purpose_wedding', 0.004516062),
#  ('sub_grade_D4', 0.004502392),
#  ('purpose_major_purchase', 0.004492171),
#  ('pub_rec_bankruptcies', 0.0044741244),
#  ('emp_length_5 years', 0.00446079),
#  ('mo_sin_old_il_acct', 0.004407077),
#  ('mths_since_recent_revol_delinq', 0.0043996256),
#  ('sub_grade_E4', 0.004397162),
#  ('tot_cur_bal', 0.0043940516),
#  ('revol_util', 0.00437384),
#  ('emp_length_1 year', 0.004350023),
#  ('delinq_amnt', 0.0043471837),
#  ('total_bal_ex_mort', 0.0042929603),
#  ('mths_since_last_major_derog', 0.0042863237),
#  ('purpose_moving', 0.004284806),
#  ('purpose_home_improvement', 0.004256366),
#  ('grade_G', 0.00425383),
#  ('tax_liens', 0.0042502005),
#  ('num_sats', 0.0042199716),
#  ('num_bc_sats', 0.0042179497),
#  ('purpose_other', 0.0041717063),
#  ('sec_app_revol_util', 0.004160388),
#  ('sub_grade_A4', 0.0041576256),
#  ('num_bc_tl', 0.0041537127),
#  ('total_acc', 0.0041400404),
#  ('il_util', 0.004125869),
#  ('emp_length_7 years', 0.0041237082),
#  ('purpose_credit_card', 0.004081503),
#  ('mths_since_recent_bc_dlq', 0.004023127),
#  ('sub_grade_B4', 0.004019302),
#  ('num_op_rev_tl', 0.003981556),
#  ('open_acc', 0.003976988),
#  ('inq_fi', 0.00391865),
#  ('sub_grade_B3', 0.0039165136),
#  ('sec_app_mths_since_last_major_derog', 0.0037429924),
#  ('revol_bal_joint', 0.003737276),
#  ('sub_grade_C3', 0.0037341516),
#  ('emp_length_6 years', 0.0037072336),
#  ('sub_grade_B5', 0.0036926144),
#  ('grade_E', 0.0036817957),
#  ('annual_inc_joint', 0.0036593648),
#  ('home_ownership_OWN', 0.003591728),
#  ('sub_grade_C5', 0.00356016),
#  ('pub_rec', 0.003426624),
#  ('sec_app_open_acc', 0.0032877473),
#  ('emp_length_8 years', 0.0032844616),
#  ('sub_grade_E5', 0.0030354252),
#  ('emp_length_2 years', 0.0030024063),
#  ('sub_grade_F2', 0.0027674756),
#  ('chargeoff_within_12_mths', 0.0027398448),
#  ('sec_app_open_act_il', 0.0027048204),
#  ('sub_grade_F3', 0.002446828),
#  ('sec_app_num_rev_accts', 0.0024341543),
#  ('home_ownership_OTHER', 0.0018712631),
#  ('fico_range_high', 0.0),
#  ('policy_code', 0.0),
#  ('sec_app_fico_range_high', 0.0),
#  ('sub_grade_B1', 0.0),
#  ('sub_grade_G1', 0.0),
#  ('sub_grade_G2', 0.0),
#  ('sub_grade_G3', 0.0),
#  ('sub_grade_G5', 0.0),
#  ('home_ownership_NONE', 0.0),
#  ('purpose_educational', 0.0),
#  ('application_type_Joint App', 0.0),
#  ('verification_status_joint_Source Verified', 0.0),
#  ('verification_status_joint_Verified', 0.0)]

# %%
from sklearn.metrics import average_precision_score
average_precision = average_precision_score(ytest_ds, gs_xgb_ds.predict(xtest_ds))

print('Average precision-recall score for random forest: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score for random forest: 0.61

# %%
# Precision-Recall curve
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve

disp = plot_precision_recall_curve(gs_xgb_ds, xtest_ds, ytest_ds)
disp.ax_.set_title('2-class Precision-Recall curve for random forest: '
                   'AP={0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, '2-class Precision-Recall curve for random forest: AP=0.61')

# %%
# F1 score 
# F1 = 2 * (precision * recall) / (precision + recall)

f1_score = metrics.f1_score(ytest_ds, gs_xgb_ds.predict(xtest_ds))
recall_score = metrics.recall_score(ytest_ds, gs_xgb_ds.predict(xtest_ds))
precision_score = metrics.precision_score(ytest_ds, gs_xgb_ds.predict(xtest_ds))
print ("Random forest performance")
print ('-'*70)
print('F1 score: {0:0.2f}'.format(f1_score))
print('recall score: {0:0.2f}'.format(recall_score))
print('precision score: {0:0.2f}'.format(precision_score))
# Out:
# Random forest performance
# ----------------------------------------------------------------------
# F1 score: 0.67
# recall score: 0.68
# precision score: 0.66

# %%
# ROC-AUC score
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html#sklearn.metrics.roc_auc_score

from sklearn.metrics import roc_auc_score
print ("Random forest ROC-AUC score")
print ('-'*70)
roc_auc_score(ytest_ds, gs_xgb_ds.predict(xtest_ds))
# Out:
# Random forest ROC-AUC score
# ----------------------------------------------------------------------
# 0.6640748729503291

# %%
# Receiver operating characteristic (ROC) curve
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_roc_curve.html#sklearn.metrics.plot_roc_curve

from sklearn import metrics
metrics.plot_roc_curve(gs_xgb_ds.best_estimator_, xtest_ds, ytest_ds)

# %%
filtered_sorted_importance = [x for x in sorted_importance if x[1]>0.003]
filtered_sorted_importance
# Out:
# [('int_rate', 0.13495792),
#  ('term_ 60 months', 0.04060569),
#  ('grade_C', 0.029782958),
#  ('home_ownership_MORTGAGE', 0.02616637),
#  ('grade_D', 0.020567523),
#  ('grade_B', 0.018797182),
#  ('home_ownership_RENT', 0.015427485),
#  ('avg_cur_bal', 0.013304356),
#  ('acc_open_past_24mths', 0.013275657),
#  ('mort_acc', 0.011543607),
#  ('purpose_small_business', 0.010741185),
#  ('num_actv_rev_tl', 0.010709896),
#  ('total_cu_tl', 0.010606778),
#  ('dti', 0.010114022),
#  ('funded_amnt', 0.009562384),
#  ('sec_app_fico_range_low', 0.009561759),
#  ('fico_range_low', 0.009349659),
#  ('all_util', 0.009177409),
#  ('sub_grade_C1', 0.008891337),
#  ('funded_amnt_inv', 0.008700782),
#  ('installment', 0.00844077),
#  ('annual_inc', 0.008371061),
#  ('delinq_2yrs', 0.008290611),
#  ('max_bal_bc', 0.008184841),
#  ('sub_grade_C2', 0.0077762464),
#  ('sub_grade_F1', 0.007593634),
#  ('verification_status_Source Verified', 0.0075656804),
#  ('purpose_vacation', 0.007373285),
#  ('loan_amnt', 0.0072820135),
#  ('initial_list_status_w', 0.007158256),
#  ('dti_joint', 0.007085065),
#  ('sub_grade_C4', 0.0070668864),
#  ('verification_status_Verified', 0.007045906),
#  ('total_bal_il', 0.006600677),
#  ('collections_12_mths_ex_med', 0.0063952636),
#  ('sub_grade_D5', 0.006362297),
#  ('grade_F', 0.0063594235),
#  ('tot_hi_cred_lim', 0.006302484),
#  ('mths_since_recent_inq', 0.0062654614),
#  ('acc_now_delinq', 0.0062138303),
#  ('mo_sin_old_rev_tl_op', 0.0062007974),
#  ('sec_app_mort_acc', 0.005859379),
#  ('purpose_renewable_energy', 0.005836658),
#  ('purpose_medical', 0.005819855),
#  ('sec_app_inq_last_6mths', 0.005724339),
#  ('sub_grade_E3', 0.005622854),
#  ('sub_grade_D2', 0.0056137205),
#  ('emp_length_4 years', 0.005555141),
#  ('sub_grade_A3', 0.0055534914),
#  ('sub_grade_F4', 0.005488423),
#  ('emp_length_10 years', 0.0054540024),
#  ('sub_grade_E1', 0.005438348),
#  ('open_act_il', 0.00543798),
#  ('mths_since_last_record', 0.0053850943),
#  ('total_bc_limit', 0.0053547113),
#  ('total_rev_hi_lim', 0.005354496),
#  ('sub_grade_A5', 0.005335519),
#  ('mths_since_recent_bc', 0.0053325673),
#  ('bc_open_to_buy', 0.0053218273),
#  ('sub_grade_A2', 0.005212536),
#  ('percent_bc_gt_75', 0.0051928875),
#  ('revol_bal', 0.005091662),
#  ('bc_util', 0.005049705),
#  ('num_rev_accts', 0.0050191474),
#  ('sub_grade_E2', 0.005001006),
#  ('num_actv_bc_tl', 0.0049951673),
#  ('sub_grade_D3', 0.0049714916),
#  ('mths_since_last_delinq', 0.0048800595),
#  ('pct_tl_nvr_dlq', 0.0048671803),
#  ('sub_grade_B2', 0.00484784),
#  ('purpose_house', 0.0048164725),
#  ('num_rev_tl_bal_gt_0', 0.004765408),
#  ('total_il_high_credit_limit', 0.004762313),
#  ('mo_sin_rcnt_tl', 0.0047621056),
#  ('num_il_tl', 0.0046917014),
#  ('sub_grade_F5', 0.0046688216),
#  ('mths_since_rcnt_il', 0.004668653),
#  ('emp_length_9 years', 0.004643099),
#  ('emp_length_3 years', 0.0046409555),
#  ('sub_grade_G4', 0.0046368837),
#  ('mo_sin_rcnt_rev_tl_op', 0.0046221297),
#  ('sub_grade_D1', 0.0046168584),
#  ('purpose_debt_consolidation', 0.0045453627),
#  ('tot_coll_amt', 0.004527774),
#  ('purpose_wedding', 0.004516062),
#  ('sub_grade_D4', 0.004502392),
#  ('purpose_major_purchase', 0.004492171),
#  ('pub_rec_bankruptcies', 0.0044741244),
#  ('emp_length_5 years', 0.00446079),
#  ('mo_sin_old_il_acct', 0.004407077),
#  ('mths_since_recent_revol_delinq', 0.0043996256),
#  ('sub_grade_E4', 0.004397162),
#  ('tot_cur_bal', 0.0043940516),
#  ('revol_util', 0.00437384),
#  ('emp_length_1 year', 0.004350023),
#  ('delinq_amnt', 0.0043471837),
#  ('total_bal_ex_mort', 0.0042929603),
#  ('mths_since_last_major_derog', 0.0042863237),
#  ('purpose_moving', 0.004284806),
#  ('purpose_home_improvement', 0.004256366),
#  ('grade_G', 0.00425383),
#  ('tax_liens', 0.0042502005),
#  ('num_sats', 0.0042199716),
#  ('num_bc_sats', 0.0042179497),
#  ('purpose_other', 0.0041717063),
#  ('sec_app_revol_util', 0.004160388),
#  ('sub_grade_A4', 0.0041576256),
#  ('num_bc_tl', 0.0041537127),
#  ('total_acc', 0.0041400404),
#  ('il_util', 0.004125869),
#  ('emp_length_7 years', 0.0041237082),
#  ('purpose_credit_card', 0.004081503),
#  ('mths_since_recent_bc_dlq', 0.004023127),
#  ('sub_grade_B4', 0.004019302),
#  ('num_op_rev_tl', 0.003981556),
#  ('open_acc', 0.003976988),
#  ('inq_fi', 0.00391865),
#  ('sub_grade_B3', 0.0039165136),
#  ('sec_app_mths_since_last_major_derog', 0.0037429924),
#  ('revol_bal_joint', 0.003737276),
#  ('sub_grade_C3', 0.0037341516),
#  ('emp_length_6 years', 0.0037072336),
#  ('sub_grade_B5', 0.0036926144),
#  ('grade_E', 0.0036817957),
#  ('annual_inc_joint', 0.0036593648),
#  ('home_ownership_OWN', 0.003591728),
#  ('sub_grade_C5', 0.00356016),
#  ('pub_rec', 0.003426624),
#  ('sec_app_open_acc', 0.0032877473),
#  ('emp_length_8 years', 0.0032844616),
#  ('sub_grade_E5', 0.0030354252),
#  ('emp_length_2 years', 0.0030024063)]

# %%
# get list of column names for easier application in the future
filter_important = []
for tup in filtered_sorted_importance:
    filter_important.append(tup[0])

filter_important
# Out:
# ['int_rate',
#  'term_ 60 months',
#  'grade_C',
#  'home_ownership_MORTGAGE',
#  'grade_D',
#  'grade_B',
#  'home_ownership_RENT',
#  'avg_cur_bal',
#  'acc_open_past_24mths',
#  'mort_acc',
#  'purpose_small_business',
#  'num_actv_rev_tl',
#  'total_cu_tl',
#  'dti',
#  'funded_amnt',
#  'sec_app_fico_range_low',
#  'fico_range_low',
#  'all_util',
#  'sub_grade_C1',
#  'funded_amnt_inv',
#  'installment',
#  'annual_inc',
#  'delinq_2yrs',
#  'max_bal_bc',
#  'sub_grade_C2',
#  'sub_grade_F1',
#  'verification_status_Source Verified',
#  'purpose_vacation',
#  'loan_amnt',
#  'initial_list_status_w',
#  'dti_joint',
#  'sub_grade_C4',
#  'verification_status_Verified',
#  'total_bal_il',
#  'collections_12_mths_ex_med',
#  'sub_grade_D5',
#  'grade_F',
#  'tot_hi_cred_lim',
#  'mths_since_recent_inq',
#  'acc_now_delinq',
#  'mo_sin_old_rev_tl_op',
#  'sec_app_mort_acc',
#  'purpose_renewable_energy',
#  'purpose_medical',
#  'sec_app_inq_last_6mths',
#  'sub_grade_E3',
#  'sub_grade_D2',
#  'emp_length_4 years',
#  'sub_grade_A3',
#  'sub_grade_F4',
#  'emp_length_10 years',
#  'sub_grade_E1',
#  'open_act_il',
#  'mths_since_last_record',
#  'total_bc_limit',
#  'total_rev_hi_lim',
#  'sub_grade_A5',
#  'mths_since_recent_bc',
#  'bc_open_to_buy',
#  'sub_grade_A2',
#  'percent_bc_gt_75',
#  'revol_bal',
#  'bc_util',
#  'num_rev_accts',
#  'sub_grade_E2',
#  'num_actv_bc_tl',
#  'sub_grade_D3',
#  'mths_since_last_delinq',
#  'pct_tl_nvr_dlq',
#  'sub_grade_B2',
#  'purpose_house',
#  'num_rev_tl_bal_gt_0',
#  'total_il_high_credit_limit',
#  'mo_sin_rcnt_tl',
#  'num_il_tl',
#  'sub_grade_F5',
#  'mths_since_rcnt_il',
#  'emp_length_9 years',
#  'emp_length_3 years',
#  'sub_grade_G4',
#  'mo_sin_rcnt_rev_tl_op',
#  'sub_grade_D1',
#  'purpose_debt_consolidation',
#  'tot_coll_amt',
#  'purpose_wedding',
#  'sub_grade_D4',
#  'purpose_major_purchase',
#  'pub_rec_bankruptcies',
#  'emp_length_5 years',
#  'mo_sin_old_il_acct',
#  'mths_since_recent_revol_delinq',
#  'sub_grade_E4',
#  'tot_cur_bal',
#  'revol_util',
#  'emp_length_1 year',
#  'delinq_amnt',
#  'total_bal_ex_mort',
#  'mths_since_last_major_derog',
#  'purpose_moving',
#  'purpose_home_improvement',
#  'grade_G',
#  'tax_liens',
#  'num_sats',
#  'num_bc_sats',
#  'purpose_other',
#  'sec_app_revol_util',
#  'sub_grade_A4',
#  'num_bc_tl',
#  'total_acc',
#  'il_util',
#  'emp_length_7 years',
#  'purpose_credit_card',
#  'mths_since_recent_bc_dlq',
#  'sub_grade_B4',
#  'num_op_rev_tl',
#  'open_acc',
#  'inq_fi',
#  'sub_grade_B3',
#  'sec_app_mths_since_last_major_derog',
#  'revol_bal_joint',
#  'sub_grade_C3',
#  'emp_length_6 years',
#  'sub_grade_B5',
#  'grade_E',
#  'annual_inc_joint',
#  'home_ownership_OWN',
#  'sub_grade_C5',
#  'pub_rec',
#  'sec_app_open_acc',
#  'emp_length_8 years',
#  'sub_grade_E5',
#  'emp_length_2 years']
